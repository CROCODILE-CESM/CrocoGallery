# %% [markdown]
# # Use CESM Output
#
# Use the "CESM_OUTPUT" product name (there's no raw data function for that and instead a raw_data path) & pass in a path to CESM data.

# %%
case.configure_forcings(
    date_range = ["2000-01-01 00:00:00", "2000-02-01 00:00:00"],
    raw_data_path = "", # Path to CESM OUTPUT data
    product_name = "CESM_OUTPUT",
)
