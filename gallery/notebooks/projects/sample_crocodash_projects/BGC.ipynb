# %% [markdown]
# # BGC Sample Project
#
#
# In this notebook, the code has the simplest regional ocean model setup possible through CrocoDash. In the comments and descriptions, we'll provide some of the ways you can add and build on this demo (recreate a specific domain - like GFDL's NWA12, run with CICE - the sea-ice model in CESM, run with MARBL - the ocean BGC model in CESM, and beyond!)
#
# This notebook is designed for new users of CrocoDash and CESM who want to set up a simple regional ocean model. By following the steps, you will learn how to generate a domain, configure a CESM case, prepare ocean forcing data, and run your simulation.
#
#
# A typical workflow of utilizing CrocoDash consists of four main steps:
#
# 1. Generate a regional MOM6 domain.
# 2. Create the CESM case.
# 3. Prepare ocean forcing data.
# 4. Build and run the case.
#
# Every specialization of CrocoDash will use this framework.

# %% [markdown]
# # SECTION 1: Generate a regional MOM6 domain
#
# We begin by defining a regional MOM6 domain using CrocoDash. To do so, we first generate a horizontal grid. We then generate the topography by remapping an existing bathymetric dataset to our horizontal grid. Finally, we define a vertical grid.

# %% [markdown]
# ## Step 1.1: Horizontal Grid

# %%
from CrocoDash.grid import Grid

grid = Grid(
  resolution = 0.05, # in degrees
  xstart = 278.0, # min longitude in [0, 360]
  lenx = 3.0, # longitude extent in degrees
  ystart = 7.0, # min latitude in [-90, 90]
  leny = 3.0, # latitude extent in degrees
  name = "panama1",
)

# Try changing the grid resolution or domain boundaries to model a different region!

# %% [markdown]
# The above cell is a way to generate a rectangular lat/lon grid through CrocoDash
#
# If you're interested in using an already generated regional grid, you can do that by passing in a supergrid, like in [this demo](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_grids.html).
#
# If you're interested in subsetting an already generated global grid, you can do that by passing in lat/lon args, like in [this demo](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/subset_global.html).

# %% [markdown]
# ## Step 1.2: Topography
#
# The below three cells are a way to generate topography with a given grid using the [GEBCO](https://www.gebco.net/) dataset.
#
# If you're interested in using a previously generated topography for your grid, you can do that by passing in a topography file, like in [this demo.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_grids.html)

# %%
from CrocoDash.topo import Topo

topo = Topo(
    grid = grid,
    min_depth = 9.5, # in meters
)

# %%
bathymetry_path='/glade/campaign/cgd/oce/projects/CROCODILE/workshops/2025/CrocoDash/data/gebco/GEBCO_2024.nc'

topo.interpolate_from_file(
    file_path = bathymetry_path,
    longitude_coordinate_name="lon",
    latitude_coordinate_name="lat",
    vertical_coordinate_name="elevation"
)
# Out:
# If bathymetry setup fails, rerun this function with write_to_file = True
# Begin regridding bathymetry...
#
# Original bathymetry size: 7.39 Mb
# Regridded size: 0.09 Mb
# Automatic regridding may fail if your domain is too big! If this process hangs or crashes,make sure function argument write_to_file = True and,open a terminal with appropriate computational and resources try calling ESMF directly in the input directory None via
#
# `mpirun -np NUMBER_OF_CPUS ESMF_Regrid -s bathymetry_original.nc -d bathymetry_unfinished.nc -m bilinear --src_var depth --dst_var depth --netcdf4 --src_regional --dst_regional`
#
# For details see https://xesmf.readthedocs.io/en/latest/large_problems_on_HPC.html
#
# Afterwards, we run the 'expt.tidy_bathymetry' method to skip the expensive interpolation step, and finishing metadata, encoding and cleanup.
#
#
#
# Regridding successful! Now calling `tidy_bathymetry` method for some finishing touches...
# setup bathymetry has finished successfully.
# Tidy bathymetry: Reading in regridded bathymetry to fix up metadata...done. Filling in inland lakes and channels...

# %%
# Validate that the topography looks right!
topo.depth.plot()

# %% [markdown]
# ### Editing the topography
#
# Regridding topography from GEBCO may result in features we do not necessarily want. The Topo Editor is a tool to edit the bathymetry as wanted. You can do things like erasing basins, opening or closing bays, or adjusting the minimum depth. On JupyterHub, remember we need the ipympl extension, which can be installed as shown on [this slide.](https://docs.google.com/presentation/d/1ZwM2YKmMumM0kggT9QpgXnizHzCdIaUdO8PBH9TR2ls/edit?slide=id.g38d23f5381c_0_0#slide=id.g38d23f5381c_0_0)

# %%
# %matplotlib ipympl
from CrocoDash.topo_editor import TopoEditor
TopoEditor(topo)
# Out:
# TopoEditor(children=(VBox(children=(HTML(value='<h2>Topo Editor</h2>'), HTML(value='<hr><h3>Display</h3>'), To…

# %% [markdown]
# ## Step 1.3: Vertical Grid
#
# The below cell generates a vertical grid using a hyperbolic function. We can also create a uniform grid instance, or use a previously generated vertical grid, like in [this demo.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_grids.html)

# %%
from CrocoDash.vgrid import VGrid

vgrid  = VGrid.hyperbolic(
    nk = 75, # number of vertical levels
    depth = topo.max_depth,
    ratio=20.0 # target ratio of top to bottom layer thicknesses
)

# %%
import matplotlib.pyplot as plt
plt.close()
# Create the plot
for depth in vgrid.z:
    plt.axhline(y=depth, linestyle='-')  # Horizontal lines

plt.ylim(max(vgrid.z) + 10, min(vgrid.z) - 10)  # Invert y-axis so deeper values go down
plt.ylabel("Depth")
plt.title("Vertical Grid")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # SECTION 2: Create the CESM case
#
# After generating the MOM6 domain, the next step is to create a CESM case using CrocoDash. This process is straightforward and involves instantiating the CrocoDash Case object. The Case object requires the following inputs:
#
#  - CESM Source Directory: A local path to a compatible CESM source copy.
#  - Case Name: A unique name for the CESM case.
#  - Input Directory: The directory where all necessary input files will be written.
#  - MOM6 Domain Objects: The horizontal grid, topography, and vertical grid created in the previous section.
#  - Project ID: (Optional) A project ID, if required by the machine.
#  - Compset: The set of models to be used in the Case. Standalone Ocean, Ocean-BGC, Ocean-Seaice, Ocean-Runoff, etc...

# %% [markdown]
# ## Step 2.1: Specify case name and directories:
#
# Begin by specifying the case name and the necessary directory paths. Ensure the CESM root directory points to your own local copy of CESM. Below is an example setup:

# %%
from pathlib import Path

# %%
# CESM case (experiment) name
casename = "pan.bgc.1"

# CESM source root (Update this path accordingly!!!)
cesmroot ="/glade/work/mlevy/codes/CESM/cesm3_0_alpha07c_CROCO/"

# Place where all your input files go 
inputdir = Path.home()/"scratch" / "croc_input" / casename
    
# CESM case directory
caseroot = Path.home() / "croc_cases" / casename

# %% [markdown]
# ## Step 2.2: Create the Case
#
# To create the CESM case, instantiate the `Case` object as shown below. This will automatically set up the CESM case based on the provided inputs: The `cesmroot` argument specifies the path to your local CESM source directory.
# The `caseroot` argument defines the directory where the case will be created. CrocoDash will handle all necessary namelist modifications and XML changes to align with the MOM6 domain objects generated earlier.
#
#
# This is where we can change the model setup to what we want:
#  - Interested in BGC? Check out [the demo for how to modify this notebook for BGC.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_bgc.html)
#  - Interested in CICE? Check out [the demo for how to modify this notebook for CICE.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_cice.html)
#  - Interested in Data Runoff from GLOFAS (or JRA)? Check out [the demo for how to modify this notebook for Data Runoff.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_rof.html)

# %%
from CrocoDash.case import Case

case = Case(
    cesmroot = cesmroot,
    caseroot = caseroot,
    inputdir = inputdir,
    ocn_grid = grid,
    ocn_vgrid = vgrid,
    ocn_topo = topo,
    project = 'ncgd0011',
    override = True,
    machine = "derecho",
    compset = "1850_DATM%JRA_SLND_SICE_MOM6%MARBL-BIO_SROF_SGLC_SWAV" # Change this as necessary to include whatever models you want. BGC? change MOM6 to MOM6%MARBL-BIO, CICE? Change SICE to CICE, GLOFAS Runoff? Change SROF to DROF%GLOFAS
)
# Out:
# INFO:  csp_solver:CspSolver initialized.
# Creating case...
#
# • Updating ccs_config/modelgrid_aliases_nuopc.xml file to include the new resolution "pan.bgc.1" consisting of the following component grids.
#  atm grid: "TL319", lnd grid: "TL319", ocn grid: "panama1".
#
# • Updating ccs_config/component_grids_nuopc.xml file to include newly generated ocean grid "panama1" with the following properties:
#  nx: 60, ny: 60. ocean mesh: /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/ocnice/ESMF_mesh_panama1_d63846.nc.
#
# Running the create_newcase tool with the following command:
#
# /glade/work/mlevy/codes/CESM/cesm3_0_alpha07c_CROCO/cime/scripts/create_newcase --compset 1850_DATM%JRA_SLND_SICE_MOM6%MARBL-BIO_SROF_SGLC_SWAV --res pan.bgc.1 --case /glade/u/home/manishrv/croc_cases/pan.bgc.1 --machine derecho --run-unsupported --project ncgd0011 --non-local
#
# The create_newcase command was successful.
#
# Navigating to the case directory:
#
# cd /glade/u/home/manishrv/croc_cases/pan.bgc.1
#
# Apply NTASK grid xml changes:
#
# ./xmlchange NTASKS_OCN=62 --non-local
#
# Running the case.setup script with the following command:
#
# ./case.setup --non-local
#
# Adding parameter changes to user_nl_mom:
#
#   ! Custom Horizonal Grid, Topography, and Vertical Grid
#   INPUTDIR = /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/ocnice
#   TRIPOLAR_N = False
#   REENTRANT_X = False
#   REENTRANT_Y = False
#   NIGLOBAL = 60
#   NJGLOBAL = 60
#   GRID_CONFIG = mosaic
#   GRID_FILE = ocean_hgrid_panama1_d63846.nc
#   TOPO_CONFIG = file
#   TOPO_FILE = ocean_topog_panama1_d63846.nc
#   MAXIMUM_DEPTH = 3431.7499950346473
#   MINIMUM_DEPTH = 9.5
#   NK = 75
#   COORD_CONFIG = none
#   ALE_COORDINATE_CONFIG = FILE:ocean_vgrid_panama1_d63846.nc
#   REGRIDDING_COORDINATE_MODE = Z*
#
#   ! Timesteps (based on grid resolution)
#   DT = 300.0
#   DT_THERM = 900.0
# INFO:	stage:SUCCESS: All stages are complete.
# Case created successfully at /glade/u/home/manishrv/croc_cases/pan.bgc.1.
#
# To further customize, build, and run the case, navigate to the case directory in your terminal. To create another case, restart the notebook.
#
# ./xmlchange MOM6_MEMORY_MODE=dynamic_symmetric --non-local
#
# ./xmlchange ROOTPE_OCN=128 --non-local

# %% [markdown]
# # Section 3: Prepare ocean forcing data
#
# We need to cut out our ocean forcing. The package expects an initial condition and one time-dependent segment per non-land boundary.
#
# In this notebook, we are forcing with the Copernicus Marine "Glorys" reanalysis dataset.
#
# ## Step 3.1 Configure Initial Conditions and Forcings
#
#  - Interested in adding tides? Check out [the demo.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_tides.html)
#  - Interested in adding chlorophyll? Check out [the demo.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_chl.html)
#  - Is the GLORYS data access function not working? Check out alternative options in [this demo.](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_data_products.html)
#
# Configure Forcings MUST be modified if BGC or Data Runoff are part of the compset (and will throw an error). Check out the demos to see the changes required: [BGC Demo](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_bgc.html), [DROF Demo](https://crocodile-cesm.github.io/CrocoGallery/notebooks/features/add_rof.html).

# %%
case.configure_forcings(
    date_range = ["2000-01-01 00:00:00", "2000-02-01 00:00:00"],
        data_input_path = "/glade/campaign/collections/cmip/CMIP6/CESM-HR/FOSI_BGC/HR/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/ocn/proc/tseries/month_1",
        product_name = "CESM_OUTPUT",
        marbl_ic_filepath = "/glade/campaign/collections/gdex/data/d651077/cesmdata/inputdata/ocn/mom/tx0.66v1/ecosys_jan_IC_omip_latlon_1x1_180W_c231221.nc",
)
# Out:
# Adding parameter changes to user_nl_mom:
#
#   ! Initial conditions
#   INIT_LAYERS_FROM_Z_FILE = True
#   Z_INIT_ALE_REMAPPING = True
#   TEMP_SALT_INIT_VERTICAL_REMAP_ONLY = True
#   DEPRESS_INITIAL_SURFACE = True
#   VELOCITY_CONFIG = file
#   TEMP_Z_INIT_FILE = TEMP_IC.nc
#   SALT_Z_INIT_FILE = SALT_IC.nc
#   Z_INIT_FILE_PTEMP_VAR = TEMP
#   Z_INIT_FILE_SALT_VAR = SALT
#   SURFACE_HEIGHT_IC_FILE = SSH_IC.nc
#   SURFACE_HEIGHT_IC_VAR = SSH
#   VELOCITY_FILE = VEL_IC.nc
#   U_IC_VAR = UVEL
#   V_IC_VAR = VVEL
#
#   ! BGC Params
#   MAX_FIELDS = 200
#   MARBL_FESEDFLUX_FILE = /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/ocnice/fesedflux_total_reduce_oxic_panama1_d63846.nc
#   MARBL_FEVENTFLUX_FILE = /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/ocnice/feventflux_5gmol_panama1_d63846.nc
#   MARBL_TRACERS_IC_FILE = ecosys_jan_IC_omip_latlon_1x1_180W_c231221.nc
#   READ_RIV_FLUXES = False
#
#   ! Open boundary conditions
#   OBC_NUMBER_OF_SEGMENTS = 4
#   OBC_FREESLIP_VORTICITY = False
#   OBC_FREESLIP_STRAIN = False
#   OBC_COMPUTED_VORTICITY = True
#   OBC_COMPUTED_STRAIN = True
#   OBC_ZERO_BIHARMONIC = True
#   OBC_TRACER_RESERVOIR_LENGTH_SCALE_OUT = 3.0E+04
#   OBC_TRACER_RESERVOIR_LENGTH_SCALE_IN = 3000.0
#   BRUSHCUTTER_MODE = True
#   OBC_SEGMENT_001 = "J=0,I=0:N,FLATHER,ORLANSKI,NUDGED,ORLANSKI_TAN,NUDGED_TAN"
#   OBC_SEGMENT_001_VELOCITY_NUDGING_TIMESCALES = 0.3, 360.0
#   OBC_SEGMENT_001_DATA = "U=file:UVEL_obc_segment_001.nc(UVEL),V=file:VVEL_obc_segment_001.nc(VVEL),SSH=file:SSH_obc_segment_001.nc(SSH),TEMP=file:TEMP_obc_segment_001.nc(TEMP),SALT=file:SALT_obc_segment_001.nc(SALT),PO4=file:PO4_obc_segment_001.nc(PO4),NO3=file:NO3_obc_segment_001.nc(NO3),SiO3=file:SiO3_obc_segment_001.nc(SiO3),NH4=file:NH4_obc_segment_001.nc(NH4),Fe=file:Fe_obc_segment_001.nc(Fe),Lig=file:Lig_obc_segment_001.nc(Lig),O2=file:O2_obc_segment_001.nc(O2),DIC=file:DIC_obc_segment_001.nc(DIC),DIC_ALT_CO2=file:DIC_ALT_CO2_obc_segment_001.nc(DIC_ALT_CO2),ALK=file:ALK_obc_segment_001.nc(ALK),ALK_ALT_CO2=file:ALK_ALT_CO2_obc_segment_001.nc(ALK_ALT_CO2),DOC=file:DOC_obc_segment_001.nc(DOC),DON=file:DON_obc_segment_001.nc(DON),DOP=file:DOP_obc_segment_001.nc(DOP),DOPr=file:DOPr_obc_segment_001.nc(DOPr),DONr=file:DONr_obc_segment_001.nc(DONr),DOCr=file:DOCr_obc_segment_001.nc(DOCr),microzooC=file:microzooC_obc_segment_001.nc(microzooC),mesozooC=file:mesozooC_obc_segment_001.nc(mesozooC),spChl=file:spChl_obc_segment_001.nc(spChl),spC=file:spC_obc_segment_001.nc(spC),spP=file:spP_obc_segment_001.nc(spP),spFe=file:spFe_obc_segment_001.nc(spFe),diatChl=file:diatChl_obc_segment_001.nc(diatChl),diatC=file:diatC_obc_segment_001.nc(diatC),diatP=file:diatP_obc_segment_001.nc(diatP),diatFe=file:diatFe_obc_segment_001.nc(diatFe),diatSi=file:diatSi_obc_segment_001.nc(diatSi),diazChl=file:diazChl_obc_segment_001.nc(diazChl),diazC=file:diazC_obc_segment_001.nc(diazC),diazP=file:diazP_obc_segment_001.nc(diazP),diazFe=file:diazFe_obc_segment_001.nc(diazFe),coccoChl=file:coccoChl_obc_segment_001.nc(coccoChl),coccoC=file:coccoC_obc_segment_001.nc(coccoC),coccoP=file:coccoP_obc_segment_001.nc(coccoP),coccoFe=file:coccoFe_obc_segment_001.nc(coccoFe),coccoCaCO3=file:coccoCaCO3_obc_segment_001.nc(coccoCaCO3)"
#   OBC_SEGMENT_002 = "J=N,I=N:0,FLATHER,ORLANSKI,NUDGED,ORLANSKI_TAN,NUDGED_TAN"
#   OBC_SEGMENT_002_VELOCITY_NUDGING_TIMESCALES = 0.3, 360.0
#   OBC_SEGMENT_002_DATA = "U=file:UVEL_obc_segment_002.nc(UVEL),V=file:VVEL_obc_segment_002.nc(VVEL),SSH=file:SSH_obc_segment_002.nc(SSH),TEMP=file:TEMP_obc_segment_002.nc(TEMP),SALT=file:SALT_obc_segment_002.nc(SALT),PO4=file:PO4_obc_segment_002.nc(PO4),NO3=file:NO3_obc_segment_002.nc(NO3),SiO3=file:SiO3_obc_segment_002.nc(SiO3),NH4=file:NH4_obc_segment_002.nc(NH4),Fe=file:Fe_obc_segment_002.nc(Fe),Lig=file:Lig_obc_segment_002.nc(Lig),O2=file:O2_obc_segment_002.nc(O2),DIC=file:DIC_obc_segment_002.nc(DIC),DIC_ALT_CO2=file:DIC_ALT_CO2_obc_segment_002.nc(DIC_ALT_CO2),ALK=file:ALK_obc_segment_002.nc(ALK),ALK_ALT_CO2=file:ALK_ALT_CO2_obc_segment_002.nc(ALK_ALT_CO2),DOC=file:DOC_obc_segment_002.nc(DOC),DON=file:DON_obc_segment_002.nc(DON),DOP=file:DOP_obc_segment_002.nc(DOP),DOPr=file:DOPr_obc_segment_002.nc(DOPr),DONr=file:DONr_obc_segment_002.nc(DONr),DOCr=file:DOCr_obc_segment_002.nc(DOCr),microzooC=file:microzooC_obc_segment_002.nc(microzooC),mesozooC=file:mesozooC_obc_segment_002.nc(mesozooC),spChl=file:spChl_obc_segment_002.nc(spChl),spC=file:spC_obc_segment_002.nc(spC),spP=file:spP_obc_segment_002.nc(spP),spFe=file:spFe_obc_segment_002.nc(spFe),diatChl=file:diatChl_obc_segment_002.nc(diatChl),diatC=file:diatC_obc_segment_002.nc(diatC),diatP=file:diatP_obc_segment_002.nc(diatP),diatFe=file:diatFe_obc_segment_002.nc(diatFe),diatSi=file:diatSi_obc_segment_002.nc(diatSi),diazChl=file:diazChl_obc_segment_002.nc(diazChl),diazC=file:diazC_obc_segment_002.nc(diazC),diazP=file:diazP_obc_segment_002.nc(diazP),diazFe=file:diazFe_obc_segment_002.nc(diazFe),coccoChl=file:coccoChl_obc_segment_002.nc(coccoChl),coccoC=file:coccoC_obc_segment_002.nc(coccoC),coccoP=file:coccoP_obc_segment_002.nc(coccoP),coccoFe=file:coccoFe_obc_segment_002.nc(coccoFe),coccoCaCO3=file:coccoCaCO3_obc_segment_002.nc(coccoCaCO3)"
#   OBC_SEGMENT_003 = "I=0,J=N:0,FLATHER,ORLANSKI,NUDGED,ORLANSKI_TAN,NUDGED_TAN"
#   OBC_SEGMENT_003_VELOCITY_NUDGING_TIMESCALES = 0.3, 360.0
#   OBC_SEGMENT_003_DATA = "U=file:UVEL_obc_segment_003.nc(UVEL),V=file:VVEL_obc_segment_003.nc(VVEL),SSH=file:SSH_obc_segment_003.nc(SSH),TEMP=file:TEMP_obc_segment_003.nc(TEMP),SALT=file:SALT_obc_segment_003.nc(SALT),PO4=file:PO4_obc_segment_003.nc(PO4),NO3=file:NO3_obc_segment_003.nc(NO3),SiO3=file:SiO3_obc_segment_003.nc(SiO3),NH4=file:NH4_obc_segment_003.nc(NH4),Fe=file:Fe_obc_segment_003.nc(Fe),Lig=file:Lig_obc_segment_003.nc(Lig),O2=file:O2_obc_segment_003.nc(O2),DIC=file:DIC_obc_segment_003.nc(DIC),DIC_ALT_CO2=file:DIC_ALT_CO2_obc_segment_003.nc(DIC_ALT_CO2),ALK=file:ALK_obc_segment_003.nc(ALK),ALK_ALT_CO2=file:ALK_ALT_CO2_obc_segment_003.nc(ALK_ALT_CO2),DOC=file:DOC_obc_segment_003.nc(DOC),DON=file:DON_obc_segment_003.nc(DON),DOP=file:DOP_obc_segment_003.nc(DOP),DOPr=file:DOPr_obc_segment_003.nc(DOPr),DONr=file:DONr_obc_segment_003.nc(DONr),DOCr=file:DOCr_obc_segment_003.nc(DOCr),microzooC=file:microzooC_obc_segment_003.nc(microzooC),mesozooC=file:mesozooC_obc_segment_003.nc(mesozooC),spChl=file:spChl_obc_segment_003.nc(spChl),spC=file:spC_obc_segment_003.nc(spC),spP=file:spP_obc_segment_003.nc(spP),spFe=file:spFe_obc_segment_003.nc(spFe),diatChl=file:diatChl_obc_segment_003.nc(diatChl),diatC=file:diatC_obc_segment_003.nc(diatC),diatP=file:diatP_obc_segment_003.nc(diatP),diatFe=file:diatFe_obc_segment_003.nc(diatFe),diatSi=file:diatSi_obc_segment_003.nc(diatSi),diazChl=file:diazChl_obc_segment_003.nc(diazChl),diazC=file:diazC_obc_segment_003.nc(diazC),diazP=file:diazP_obc_segment_003.nc(diazP),diazFe=file:diazFe_obc_segment_003.nc(diazFe),coccoChl=file:coccoChl_obc_segment_003.nc(coccoChl),coccoC=file:coccoC_obc_segment_003.nc(coccoC),coccoP=file:coccoP_obc_segment_003.nc(coccoP),coccoFe=file:coccoFe_obc_segment_003.nc(coccoFe),coccoCaCO3=file:coccoCaCO3_obc_segment_003.nc(coccoCaCO3)"
#   OBC_SEGMENT_004 = "I=N,J=0:N,FLATHER,ORLANSKI,NUDGED,ORLANSKI_TAN,NUDGED_TAN"
#   OBC_SEGMENT_004_VELOCITY_NUDGING_TIMESCALES = 0.3, 360.0
#   OBC_SEGMENT_004_DATA = "U=file:UVEL_obc_segment_004.nc(UVEL),V=file:VVEL_obc_segment_004.nc(VVEL),SSH=file:SSH_obc_segment_004.nc(SSH),TEMP=file:TEMP_obc_segment_004.nc(TEMP),SALT=file:SALT_obc_segment_004.nc(SALT),PO4=file:PO4_obc_segment_004.nc(PO4),NO3=file:NO3_obc_segment_004.nc(NO3),SiO3=file:SiO3_obc_segment_004.nc(SiO3),NH4=file:NH4_obc_segment_004.nc(NH4),Fe=file:Fe_obc_segment_004.nc(Fe),Lig=file:Lig_obc_segment_004.nc(Lig),O2=file:O2_obc_segment_004.nc(O2),DIC=file:DIC_obc_segment_004.nc(DIC),DIC_ALT_CO2=file:DIC_ALT_CO2_obc_segment_004.nc(DIC_ALT_CO2),ALK=file:ALK_obc_segment_004.nc(ALK),ALK_ALT_CO2=file:ALK_ALT_CO2_obc_segment_004.nc(ALK_ALT_CO2),DOC=file:DOC_obc_segment_004.nc(DOC),DON=file:DON_obc_segment_004.nc(DON),DOP=file:DOP_obc_segment_004.nc(DOP),DOPr=file:DOPr_obc_segment_004.nc(DOPr),DONr=file:DONr_obc_segment_004.nc(DONr),DOCr=file:DOCr_obc_segment_004.nc(DOCr),microzooC=file:microzooC_obc_segment_004.nc(microzooC),mesozooC=file:mesozooC_obc_segment_004.nc(mesozooC),spChl=file:spChl_obc_segment_004.nc(spChl),spC=file:spC_obc_segment_004.nc(spC),spP=file:spP_obc_segment_004.nc(spP),spFe=file:spFe_obc_segment_004.nc(spFe),diatChl=file:diatChl_obc_segment_004.nc(diatChl),diatC=file:diatC_obc_segment_004.nc(diatC),diatP=file:diatP_obc_segment_004.nc(diatP),diatFe=file:diatFe_obc_segment_004.nc(diatFe),diatSi=file:diatSi_obc_segment_004.nc(diatSi),diazChl=file:diazChl_obc_segment_004.nc(diazChl),diazC=file:diazC_obc_segment_004.nc(diazC),diazP=file:diazP_obc_segment_004.nc(diazP),diazFe=file:diazFe_obc_segment_004.nc(diazFe),coccoChl=file:coccoChl_obc_segment_004.nc(coccoChl),coccoC=file:coccoC_obc_segment_004.nc(coccoC),coccoP=file:coccoP_obc_segment_004.nc(coccoP),coccoFe=file:coccoFe_obc_segment_004.nc(coccoFe),coccoCaCO3=file:coccoCaCO3_obc_segment_004.nc(coccoCaCO3)"
#
# ./xmlchange RUN_STARTDATE=2000-01-01 --non-local
#
# ./xmlchange STOP_OPTION=ndays --non-local
#
# ./xmlchange STOP_N=32 --non-local

# %% [markdown]
# ##  Step 3.3: Process forcing data
#
# In this final step, we call the `process_forcings` method of CrocoDash to cut out and interpolate the initial condition as well as all boundaries. CrocoDash also updates MOM6 runtime parameters and CESM xml variables accordingly.

# %%
case.process_forcings() # You can turn off specific processing if it's already been processed previously with process_*name* = False. Ex. case.process_forcings(process_chl = False)
# Out:
# Parsing dataset...
# 1 file(s) found for variable 'UVEL'
# 1 file(s) found for variable 'VVEL'
# 1 file(s) found for variable 'SSH'
# 1 file(s) found for variable 'TEMP'
# 1 file(s) found for variable 'SALT'
# 1 file(s) found for variable 'PO4'
# 1 file(s) found for variable 'NO3'
# 1 file(s) found for variable 'SiO3'
# 1 file(s) found for variable 'NH4'
# 1 file(s) found for variable 'Fe'
# 1 file(s) found for variable 'Lig'
# 1 file(s) found for variable 'O2'
# 1 file(s) found for variable 'DIC'
# 1 file(s) found for variable 'DIC_ALT_CO2'
# 1 file(s) found for variable 'ALK'
# 1 file(s) found for variable 'ALK_ALT_CO2'
# 1 file(s) found for variable 'DOC'
# 1 file(s) found for variable 'DON'
# 1 file(s) found for variable 'DOP'
# 1 file(s) found for variable 'DOPr'
# 1 file(s) found for variable 'DONr'
# 1 file(s) found for variable 'DOCr'
# 1 file(s) found for variable 'microzooC'
# 1 file(s) found for variable 'mesozooC'
# 1 file(s) found for variable 'spChl'
# 1 file(s) found for variable 'spC'
# 1 file(s) found for variable 'spP'
# 1 file(s) found for variable 'spFe'
# 1 file(s) found for variable 'diatChl'
# 1 file(s) found for variable 'diatC'
# 1 file(s) found for variable 'diatP'
# 1 file(s) found for variable 'diatFe'
# 1 file(s) found for variable 'diatSi'
# 1 file(s) found for variable 'diazChl'
# 1 file(s) found for variable 'diazC'
# 1 file(s) found for variable 'diazP'
# 1 file(s) found for variable 'diazFe'
# 1 file(s) found for variable 'coccoChl'
# 1 file(s) found for variable 'coccoC'
# 1 file(s) found for variable 'coccoP'
# 1 file(s) found for variable 'coccoFe'
# 1 file(s) found for variable 'coccoCaCO3'
# Subsetted dataset for variable 'UVEL' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/UVEL_subset.nc
# Subsetted dataset for variable 'VVEL' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/VVEL_subset.nc
# Subsetted dataset for variable 'SSH' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/SSH_subset.nc
# Subsetted dataset for variable 'TEMP' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/TEMP_subset.nc
# Subsetted dataset for variable 'SALT' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/SALT_subset.nc
# Subsetted dataset for variable 'PO4' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/PO4_subset.nc
# Subsetted dataset for variable 'NO3' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/NO3_subset.nc
# Subsetted dataset for variable 'SiO3' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/SiO3_subset.nc
# Subsetted dataset for variable 'NH4' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/NH4_subset.nc
# Subsetted dataset for variable 'Fe' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/Fe_subset.nc
# Subsetted dataset for variable 'Lig' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/Lig_subset.nc
# Subsetted dataset for variable 'O2' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/O2_subset.nc
# Subsetted dataset for variable 'DIC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DIC_subset.nc
# Subsetted dataset for variable 'DIC_ALT_CO2' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DIC_ALT_CO2_subset.nc
# Subsetted dataset for variable 'ALK' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/ALK_subset.nc
# Subsetted dataset for variable 'ALK_ALT_CO2' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/ALK_ALT_CO2_subset.nc
# Subsetted dataset for variable 'DOC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DOC_subset.nc
# Subsetted dataset for variable 'DON' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DON_subset.nc
# Subsetted dataset for variable 'DOP' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DOP_subset.nc
# Subsetted dataset for variable 'DOPr' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DOPr_subset.nc
# Subsetted dataset for variable 'DONr' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DONr_subset.nc
# Subsetted dataset for variable 'DOCr' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/DOCr_subset.nc
# Subsetted dataset for variable 'microzooC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/microzooC_subset.nc
# Subsetted dataset for variable 'mesozooC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/mesozooC_subset.nc
# Subsetted dataset for variable 'spChl' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/spChl_subset.nc
# Subsetted dataset for variable 'spC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/spC_subset.nc
# Subsetted dataset for variable 'spP' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/spP_subset.nc
# Subsetted dataset for variable 'spFe' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/spFe_subset.nc
# Subsetted dataset for variable 'diatChl' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diatChl_subset.nc
# Subsetted dataset for variable 'diatC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diatC_subset.nc
# Subsetted dataset for variable 'diatP' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diatP_subset.nc
# Subsetted dataset for variable 'diatFe' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diatFe_subset.nc
# Subsetted dataset for variable 'diatSi' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diatSi_subset.nc
# Subsetted dataset for variable 'diazChl' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diazChl_subset.nc
# Subsetted dataset for variable 'diazC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diazC_subset.nc
# Subsetted dataset for variable 'diazP' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diazP_subset.nc
# Subsetted dataset for variable 'diazFe' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/diazFe_subset.nc
# Subsetted dataset for variable 'coccoChl' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/coccoChl_subset.nc
# Subsetted dataset for variable 'coccoC' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/coccoC_subset.nc
# Subsetted dataset for variable 'coccoP' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/coccoP_subset.nc
# Subsetted dataset for variable 'coccoFe' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/coccoFe_subset.nc
# INFO:regional_mom6.regridding:Getting t points..
# INFO:regional_mom6.regridding:Getting v points..
# INFO:regional_mom6.regridding:Getting u points..
# INFO:regional_mom6.regridding:Creating Regridder
# Subsetted dataset for variable 'coccoCaCO3' saved to /glade/u/home/manishrv/scratch/croc_input/pan.bgc.1/cesm_output/cesm_output_extract_obc_workflow/subsetted_data/coccoCaCO3_subset.nc
# INFO:regional_mom6.regridding:Creating Regridder
# INFO:regional_mom6.regridding:Creating Regridder
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Creating Regridder
# Creating regridder for IC
# Creating regridder for west
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Creating Regridder
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Creating Regridder
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Creating Regridder
# Creating regridder for south
# Creating regridder for north
# Creating regridder for east
# Regridding UVEL IC
# UVEL IC regridded
# Regridding VVEL IC
# VVEL IC regridded
# Regridding SSH IC
# SSH IC regridded
# Regridding TEMP IC
# TEMP IC regridded
# Regridding SALT IC
# SALT IC regridded
# Regridding UVEL west
# UVEL west regridded
# Regridding VVEL west
# VVEL west regridded
# Regridding SSH west
# SSH west regridded
# Regridding TEMP west
# TEMP west regridded
# Regridding SALT west
# SALT west regridded
# Regridding PO4 west
# PO4 west regridded
# Regridding NO3 west
# NO3 west regridded
# Regridding SiO3 west
# SiO3 west regridded
# Regridding NH4 west
# NH4 west regridded
# Regridding Fe west
# Fe west regridded
# Regridding Lig west
# Lig west regridded
# Regridding O2 west
# O2 west regridded
# Regridding DIC west
# DIC west regridded
# Regridding DIC_ALT_CO2 west
# DIC_ALT_CO2 west regridded
# Regridding ALK west
# ALK west regridded
# Regridding ALK_ALT_CO2 west
# ALK_ALT_CO2 west regridded
# Regridding DOC west
# DOC west regridded
# Regridding DON west
# DON west regridded
# Regridding DOP west
# DOP west regridded
# Regridding DOPr west
# DOPr west regridded
# Regridding DONr west
# DONr west regridded
# Regridding DOCr west
# DOCr west regridded
# Regridding microzooC west
# microzooC west regridded
# Regridding mesozooC west
# mesozooC west regridded
# Regridding spChl west
# spChl west regridded
# Regridding spC west
# spC west regridded
# Regridding spP west
# spP west regridded
# Regridding spFe west
# spFe west regridded
# Regridding diatChl west
# diatChl west regridded
# Regridding diatC west
# diatC west regridded
# Regridding diatP west
# diatP west regridded
# Regridding diatFe west
# diatFe west regridded
# Regridding diatSi west
# diatSi west regridded
# Regridding diazChl west
# diazChl west regridded
# Regridding diazC west
# diazC west regridded
# Regridding diazP west
# diazP west regridded
# Regridding diazFe west
# diazFe west regridded
# Regridding coccoChl west
# coccoChl west regridded
# Regridding coccoC west
# coccoC west regridded
# Regridding coccoP west
# coccoP west regridded
# Regridding coccoFe west
# coccoFe west regridded
# Regridding coccoCaCO3 west
# coccoCaCO3 west regridded
# Regridding UVEL south
# UVEL south regridded
# Regridding VVEL south
# VVEL south regridded
# Regridding SSH south
# SSH south regridded
# Regridding TEMP south
# TEMP south regridded
# Regridding SALT south
# SALT south regridded
# Regridding PO4 south
# PO4 south regridded
# Regridding NO3 south
# NO3 south regridded
# Regridding SiO3 south
# SiO3 south regridded
# Regridding NH4 south
# NH4 south regridded
# Regridding Fe south
# Fe south regridded
# Regridding Lig south
# Lig south regridded
# Regridding O2 south
# O2 south regridded
# Regridding DIC south
# DIC south regridded
# Regridding DIC_ALT_CO2 south
# DIC_ALT_CO2 south regridded
# Regridding ALK south
# ALK south regridded
# Regridding ALK_ALT_CO2 south
# ALK_ALT_CO2 south regridded
# Regridding DOC south
# DOC south regridded
# Regridding DON south
# DON south regridded
# Regridding DOP south
# DOP south regridded
# Regridding DOPr south
# DOPr south regridded
# Regridding DONr south
# DONr south regridded
# Regridding DOCr south
# DOCr south regridded
# Regridding microzooC south
# microzooC south regridded
# Regridding mesozooC south
# mesozooC south regridded
# Regridding spChl south
# spChl south regridded
# Regridding spC south
# spC south regridded
# Regridding spP south
# spP south regridded
# Regridding spFe south
# spFe south regridded
# Regridding diatChl south
# diatChl south regridded
# Regridding diatC south
# diatC south regridded
# Regridding diatP south
# diatP south regridded
# Regridding diatFe south
# diatFe south regridded
# Regridding diatSi south
# diatSi south regridded
# Regridding diazChl south
# diazChl south regridded
# Regridding diazC south
# diazC south regridded
# Regridding diazP south
# diazP south regridded
# Regridding diazFe south
# diazFe south regridded
# Regridding coccoChl south
# coccoChl south regridded
# Regridding coccoC south
# coccoC south regridded
# Regridding coccoP south
# coccoP south regridded
# Regridding coccoFe south
# coccoFe south regridded
# Regridding coccoCaCO3 south
# coccoCaCO3 south regridded
# Regridding UVEL north
# UVEL north regridded
# Regridding VVEL north
# VVEL north regridded
# Regridding SSH north
# SSH north regridded
# Regridding TEMP north
# TEMP north regridded
# Regridding SALT north
# SALT north regridded
# Regridding PO4 north
# PO4 north regridded
# Regridding NO3 north
# NO3 north regridded
# Regridding SiO3 north
# SiO3 north regridded
# Regridding NH4 north
# NH4 north regridded
# Regridding Fe north
# Fe north regridded
# Regridding Lig north
# Lig north regridded
# Regridding O2 north
# O2 north regridded
# Regridding DIC north
# DIC north regridded
# Regridding DIC_ALT_CO2 north
# DIC_ALT_CO2 north regridded
# Regridding ALK north
# ALK north regridded
# Regridding ALK_ALT_CO2 north
# ALK_ALT_CO2 north regridded
# Regridding DOC north
# DOC north regridded
# Regridding DON north
# DON north regridded
# Regridding DOP north
# DOP north regridded
# Regridding DOPr north
# DOPr north regridded
# Regridding DONr north
# DONr north regridded
# Regridding DOCr north
# DOCr north regridded
# Regridding microzooC north
# microzooC north regridded
# Regridding mesozooC north
# mesozooC north regridded
# Regridding spChl north
# spChl north regridded
# Regridding spC north
# spC north regridded
# Regridding spP north
# spP north regridded
# Regridding spFe north
# spFe north regridded
# Regridding diatChl north
# diatChl north regridded
# Regridding diatC north
# diatC north regridded
# Regridding diatP north
# diatP north regridded
# Regridding diatFe north
# diatFe north regridded
# Regridding diatSi north
# diatSi north regridded
# Regridding diazChl north
# diazChl north regridded
# Regridding diazC north
# diazC north regridded
# Regridding diazP north
# diazP north regridded
# Regridding diazFe north
# diazFe north regridded
# Regridding coccoChl north
# coccoChl north regridded
# Regridding coccoC north
# coccoC north regridded
# Regridding coccoP north
# coccoP north regridded
# Regridding coccoFe north
# coccoFe north regridded
# Regridding coccoCaCO3 north
# coccoCaCO3 north regridded
# Regridding UVEL east
# UVEL east regridded
# Regridding VVEL east
# VVEL east regridded
# Regridding SSH east
# SSH east regridded
# Regridding TEMP east
# TEMP east regridded
# Regridding SALT east
# SALT east regridded
# Regridding PO4 east
# PO4 east regridded
# Regridding NO3 east
# NO3 east regridded
# Regridding SiO3 east
# SiO3 east regridded
# Regridding NH4 east
# NH4 east regridded
# Regridding Fe east
# Fe east regridded
# Regridding Lig east
# Lig east regridded
# Regridding O2 east
# O2 east regridded
# Regridding DIC east
# DIC east regridded
# Regridding DIC_ALT_CO2 east
# DIC_ALT_CO2 east regridded
# Regridding ALK east
# ALK east regridded
# Regridding ALK_ALT_CO2 east
# ALK_ALT_CO2 east regridded
# Regridding DOC east
# DOC east regridded
# Regridding DON east
# DON east regridded
# Regridding DOP east
# DOP east regridded
# Regridding DOPr east
# DOPr east regridded
# Regridding DONr east
# DONr east regridded
# Regridding DOCr east
# DOCr east regridded
# Regridding microzooC east
# microzooC east regridded
# Regridding mesozooC east
# mesozooC east regridded
# Regridding spChl east
# spChl east regridded
# Regridding spC east
# spC east regridded
# Regridding spP east
# spP east regridded
# Regridding spFe east
# spFe east regridded
# Regridding diatChl east
# diatChl east regridded
# Regridding diatC east
# diatC east regridded
# Regridding diatP east
# diatP east regridded
# Regridding diatFe east
# diatFe east regridded
# Regridding diatSi east
# diatSi east regridded
# Regridding diazChl east
# diazChl east regridded
# Regridding diazC east
# diazC east regridded
# Regridding diazP east
# diazP east regridded
# Regridding diazFe east
# diazFe east regridded
# Regridding coccoChl east
# coccoChl east regridded
# Regridding coccoC east
# coccoC east regridded
# Regridding coccoP east
# coccoP east regridded
# Regridding coccoFe east
# coccoFe east regridded
# Regridding coccoCaCO3 east
# coccoCaCO3 east regridded
# INFO:regional_mom6.regridding:Getting u points..
# INFO:regional_mom6.regridding:Getting v points..
# INFO:regional_mom6.regridding:Getting t points..
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# Converting the UVEL variable because it is distance based with factor 0.01
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in UVEL_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to UVEL_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in UVEL_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to UVEL_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in UVEL_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to UVEL_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in UVEL_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to UVEL_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Getting u points..
# INFO:regional_mom6.regridding:Getting v points..
# INFO:regional_mom6.regridding:Getting t points..
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# ....Finished UVEL IC processing!
# Converting the UVEL variable because it is distance based with factor 0.01
# ....Finished UVEL west processing!
# Converting the UVEL variable because it is distance based with factor 0.01
# ....Finished UVEL south processing!
# Converting the UVEL variable because it is distance based with factor 0.01
# ....Finished UVEL north processing!
# Converting the UVEL variable because it is distance based with factor 0.01
# ....Finished UVEL east processing!
# Converting the VVEL variable because it is distance based with factor 0.01
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in VVEL_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to VVEL_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in VVEL_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to VVEL_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in VVEL_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to VVEL_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in VVEL_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to VVEL_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished VVEL IC processing!
# Converting the VVEL variable because it is distance based with factor 0.01
# ....Finished VVEL west processing!
# Converting the VVEL variable because it is distance based with factor 0.01
# ....Finished VVEL south processing!
# Converting the VVEL variable because it is distance based with factor 0.01
# ....Finished VVEL north processing!
# Converting the VVEL variable because it is distance based with factor 0.01
# ....Finished VVEL east processing!
# INFO:regional_mom6.regridding:Getting u points..
# INFO:regional_mom6.regridding:Getting v points..
# INFO:regional_mom6.regridding:Getting t points..
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SSH_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# Did not find any of the provided z_dims in the dataset for SSH IC, assuming surface variable
# Converting the SSH variable because it is distance based with factor 0.01
# ....Finished SSH IC processing!
# Did not find any of the provided z_dims in the dataset for SSH west, assuming surface variable
# Converting the SSH variable because it is distance based with factor 0.01
# This variable is only a surface variable, skipping z_dim_act conversion.
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SSH_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SSH_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SSH_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Getting u points..
# INFO:regional_mom6.regridding:Getting v points..
# INFO:regional_mom6.regridding:Getting t points..
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in TEMP_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to TEMP_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished SSH west processing!
# Did not find any of the provided z_dims in the dataset for SSH south, assuming surface variable
# Converting the SSH variable because it is distance based with factor 0.01
# This variable is only a surface variable, skipping z_dim_act conversion.
# ....Finished SSH south processing!
# Did not find any of the provided z_dims in the dataset for SSH north, assuming surface variable
# Converting the SSH variable because it is distance based with factor 0.01
# This variable is only a surface variable, skipping z_dim_act conversion.
# ....Finished SSH north processing!
# Did not find any of the provided z_dims in the dataset for SSH east, assuming surface variable
# Converting the SSH variable because it is distance based with factor 0.01
# This variable is only a surface variable, skipping z_dim_act conversion.
# ....Finished SSH east processing!
# ....Finished TEMP IC processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in TEMP_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to TEMP_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in TEMP_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to TEMP_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in TEMP_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to TEMP_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Getting u points..
# INFO:regional_mom6.regridding:Getting v points..
# INFO:regional_mom6.regridding:Getting t points..
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# ....Finished TEMP west processing!
# ....Finished TEMP south processing!
# ....Finished TEMP north processing!
# ....Finished TEMP east processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SALT_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SALT_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SALT_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SALT_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SALT_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SALT_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SALT_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SALT_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in PO4_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to PO4_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished SALT IC processing!
# ....Finished SALT west processing!
# ....Finished SALT south processing!
# ....Finished SALT north processing!
# ....Finished SALT east processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in PO4_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to PO4_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in PO4_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to PO4_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in PO4_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to PO4_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NO3_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NO3_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NO3_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NO3_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished PO4 west processing!
# ....Finished PO4 south processing!
# ....Finished PO4 north processing!
# ....Finished PO4 east processing!
# ....Finished NO3 west processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NO3_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NO3_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NO3_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NO3_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SiO3_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SiO3_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SiO3_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SiO3_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SiO3_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SiO3_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# ....Finished NO3 south processing!
# ....Finished NO3 north processing!
# ....Finished NO3 east processing!
# ....Finished SiO3 west processing!
# ....Finished SiO3 south processing!
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in SiO3_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to SiO3_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NH4_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NH4_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NH4_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NH4_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NH4_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NH4_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in NH4_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to NH4_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished SiO3 north processing!
# ....Finished SiO3 east processing!
# ....Finished NH4 west processing!
# ....Finished NH4 south processing!
# ....Finished NH4 north processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Fe_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Fe_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Fe_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Fe_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Fe_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Fe_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Fe_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Fe_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# ....Finished NH4 east processing!
# ....Finished Fe west processing!
# ....Finished Fe south processing!
# ....Finished Fe north processing!
# ....Finished Fe east processing!
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Lig_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Lig_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Lig_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Lig_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Lig_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Lig_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in Lig_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to Lig_segment_004
# ...
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in diazFe_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to diazFe_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in diazFe_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to diazFe_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished diazP west processing!
# ....Finished diazP south processing!
# ....Finished diazP north processing!
# ....Finished diazP east processing!
# ....Finished diazFe west processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in diazFe_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to diazFe_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in diazFe_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to diazFe_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoChl_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoChl_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoChl_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoChl_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoChl_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoChl_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# ....Finished diazFe south processing!
# ....Finished diazFe north processing!
# ....Finished diazFe east processing!
# ....Finished coccoChl west processing!
# ....Finished coccoChl south processing!
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoChl_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoChl_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoC_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoC_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoC_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoC_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoC_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoC_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoC_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoC_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# ....Finished coccoChl north processing!
# ....Finished coccoChl east processing!
# ....Finished coccoC west processing!
# ....Finished coccoC south processing!
# ....Finished coccoC north processing!
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoP_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoP_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoP_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoP_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoP_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoP_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoP_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoP_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoFe_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoFe_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished coccoC east processing!
# ....Finished coccoP west processing!
# ....Finished coccoP south processing!
# ....Finished coccoP north processing!
# ....Finished coccoP east processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoFe_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoFe_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoFe_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoFe_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoFe_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoFe_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoCaCO3_segment_003
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoCaCO3_segment_003
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoCaCO3_segment_001
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoCaCO3_segment_001
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished coccoFe west processing!
# ....Finished coccoFe south processing!
# ....Finished coccoFe north processing!
# ....Finished coccoFe east processing!
# ....Finished coccoCaCO3 west processing!
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoCaCO3_segment_002
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoCaCO3_segment_002
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Creating coordinates of the boundary q/u/v points
# INFO:regional_mom6.regridding:Filling in missing data horizontally, then vertically
# INFO:regional_mom6.regridding:Renaming vertical coordinate to nz_... in coccoCaCO3_segment_004
# INFO:regional_mom6.regridding:Replacing old depth coordinates with incremental integers
# INFO:regional_mom6.regridding:Adding perpendicular dimension to coccoCaCO3_segment_004
# INFO:regional_mom6.regridding:Masking to bathymetry. If you don't want this, set bathymetry_path to None in the segment class.
# INFO:regional_mom6.regridding:Generating encoding dictionary
# INFO:regional_mom6.regridding:Generating encoding dictionary
# ....Finished coccoCaCO3 south processing!
# ....Finished coccoCaCO3 north processing!
# ....Finished coccoCaCO3 east processing!
# Merging U & V velocity files
# Case is ready to be built: /glade/u/home/manishrv/croc_cases/pan.bgc.1

# %% [markdown]
# # Section 4: Build and run the case
#
# After completing the previous steps, you are ready to build and run your CESM case. Begin by navigating to the case root directory specified during the case creation. Before proceeding, review the `user_nl_mom` file located in the case directory. This file contains MOM6 parameter settings that were automatically generated by CrocoDash. Carefully examine these parameters and make any necessary adjustments to fine-tune the model for your specific requirements. While CrocoDash aims to provide a solid starting point, further tuning and adjustments are typically necessary to improve the model for your use case.
#
# Once you have reviewed and modified the parameters as needed, you can build and execute the case using the following commands:
# ```
# qcmd -- ./case.build
# ./case.submit
# ```
